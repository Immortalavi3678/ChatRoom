# %% [markdown]
# # math

# %%
import math as m
dir(m)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
m.pi
# Out:
# 3.141592653589793

# %%
m.log(1)
# Out:
# 0.0

# %% [markdown]
# # random

# %%
import random as r

# %%
dir(r)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_Sequence',
#  '_Set',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_floor',
#  '_inst',
#  '_log',
#  '_os',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  '_warn',
#  'betavariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
#  'vonmisesvariate',
#  'weibullvariate']

# %%
r.random()
# Out:
# 0.046252235452031165

# %%
r.randint(1000,9999)
# Out:
# 1084

# %%
g = ["mango","apple","grapes"]

r.choice(g),r.choice(g)
# Out:
# ('mango', 'grapes')

# %%
r.choices(g,k=2)
# Out:
# ['grapes', 'mango']

# %%
g
# Out:
# ['mango', 'apple', 'grapes']

# %%
r.shuffle(g)
g
# Out:
# ['grapes', 'apple', 'mango']

# %% [markdown]
# # os

# %%
import os

# %%
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_KILLED',
#  'CLD_STOPPED',
#  'CLD_TRAPPED',
#  'DirEntry',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EXCL',
#  'O_EXLOCK',
#  'O_NDELAY',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NONBLOCK',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SHLOCK',
#  'O_SYNC',
#  'O_TRUNC',
#  'O_WRONLY',
#  'POSIX_SPAWN_CLOSE',
#  'POSIX_SPAWN_DUP2',
#  'POSIX_SPAWN_OPEN',
#  'PRIO_PGRP',
#  'PRIO_PROCESS',
#  'PRIO_USER',
#  'P_ALL',
#  'P_NOWAIT',
#  'P_NOWAITO',
#  'P_PGID',
#  'P_PID',
# ...

# %%
os.listdir()
# Out:
# ['while_stats.ipynb',
#  'conditional_statements.ipynb',
#  '__pycache__',
#  'test.py',
#  'modules_train.ipynb',
#  'functions.ipynb',
#  'modules_concept.py',
#  'list_tuple_dict_sets.ipynb',
#  '.ipynb_checkpoints',
#  'test.ipynb']

# %%
os.getcwd()
# Out:
# '/Users/sreekantht/Desktop/ITM Python'

# %%
os.path.join("desktop","folder1","file")
# Out:
# 'desktop/folder1/file'

# %%
os.system("start mspaint")
# Out:
# Package                                           Version
# ------------------------------------------------- ------------
# absl-py                                           0.10.0
# aio-pika                                          6.8.2
# aiofiles                                          0.8.0
# aiohttp                                           3.6.3
# aiormq                                            3.3.1
# alembic                                           1.7.7
# antlr4-python3-runtime                            4.8
# anyio                                             3.5.0
# appdirs                                           1.4.4
# appnope                                           0.1.3
# APScheduler                                       3.6.3
# argon2-cffi                                       21.3.0
# argon2-cffi-bindings                              21.2.0
# asteroid-filterbanks                              0.4.0
# astunparse                                        1.6.3
# ...

# %%
os.environ
# Out:
# environ{'ELECTRON_RUN_AS_NODE': '1',
#         'TERM_PROGRAM': 'Apple_Terminal',
#         'SHELL': '/bin/zsh',
#         'TERM': 'xterm-color',
#         'TMPDIR': '/var/folders/yt/9gjj_dzn30303k5vgx4054c80000gn/T/',
#         'TERM_PROGRAM_VERSION': '433',
#         'TERM_SESSION_ID': 'A4CF7DF6-1111-4162-B8D9-5A169FC51C7D',
#         'ZSH': '/Users/sreekantht/.oh-my-zsh',
#         'USER': 'sreekantht',
#         'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.AcvkCV4XgT/Listeners',
#         'PAGER': 'cat',
#         'LSCOLORS': 'Gxfxcxdxbxegedabagacad',
#         'PATH': '/usr/local/bin:/Library/Frameworks/Python.framework/Versions/3.7/bin:/Library/Frameworks/Python.framework/Versions/3.9/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin',
#         'PWD': '/Users/sreekantht/Desktop/ITM Python',
#         'XPC_FLAGS': '0x0',
#         'XPC_SERVICE_NAME': '0',
#         'SHLVL': '2',
#         'HOME': '/Users/sreekantht',
#         'LESS': '-R',
#         'LOGNAME': 'sreekantht',
# ...

# %% [markdown]
# # sys

# %%
import sys

# %%
sys.path
# Out:
# ['/Users/sreekantht/Desktop/ITM Python',
#  '/Library/Frameworks/Python.framework/Versions/3.9/lib/python39.zip',
#  '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9',
#  '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/lib-dynload',
#  '',
#  '/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages']
